# %%
import matplotlib.pyplot as plt
from scipy.io import loadmat
import numpy as np
import cv2

# %%
import os

os.path.realpath('read_annotations.ipynb')
# Out:
# '/home/kacper/Documents/Studia/Semester 5/Computer Vision/Human-Pose-Estimation/src/read_annotations.ipynb'

# %%
# main_path = os.path.dirname(os.path.realpath('__file__'))
# file_path = os.path.join(main_path, 'data/annotations.mat')
annotations = loadmat('/home/kacper/Documents/Studia/Semester 5/Computer Vision/Human-Pose-Estimation/data/annotations.mat', squeeze_me=True, chars_as_strings=True,
struct_as_record=False, verify_compressed_data_integrity=True, simplify_cells=True)

# %%
annotations
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: GLNXA64, Created on: Tue Sep 23 22:09:02 2014',
#  '__version__': '1.0',
#  '__globals__': [],
#  'RELEASE': {'annolist': [{'image': {'name': '037454012.jpg'},
#     'annorect': {'scale': 3.8807339512004684, 'objpos': {'x': 601, 'y': 380}},
#     'frame_sec': array([], dtype=float64),
#     'vididx': array([], dtype=float64)},
#    {'image': {'name': '095071431.jpg'},
#     'annorect': [{'scale': 8.078166128521993, 'objpos': {'x': 881, 'y': 394}},
#      {'scale': 8.90412937911394, 'objpos': {'x': 338, 'y': 210}}],
#     'frame_sec': array([], dtype=float64),
#     'vididx': array([], dtype=float64)},
#    {'image': {'name': '073199394.jpg'},
#     'annorect': {'scale': 4.3266615305567875, 'objpos': {'x': 619, 'y': 350}},
#     'frame_sec': array([], dtype=float64),
#     'vididx': array([], dtype=float64)},
#    {'image': {'name': '059865848.jpg'},
#     'annorect': {'scale': 4.928480496055553, 'objpos': {'x': 684, 'y': 309}},
# ...

# %%
count = 0
imgidxs = []
for imgidx in range(len(annotations['RELEASE']['single_person'])):
    if type(annotations['RELEASE']['single_person'][imgidx]) != np.ndarray:
        if annotations['RELEASE']['single_person'][imgidx] == 1:
            count +=1
            imgidxs.append(imgidx)
print(count)
# Out:
# 16093

# %%
annotations['RELEASE']['annolist'][imgidxs[1]]
# Out:
# {'image': {'name': '073199394.jpg'},
#  'annorect': {'scale': 4.3266615305567875, 'objpos': {'x': 619, 'y': 350}},
#  'frame_sec': array([], dtype=float64),
#  'vididx': array([], dtype=float64)}

# %%
def plot_and_annotate(name, points):
    img = cv2.imread(name)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    # for x,y in points:
    #     cv2.circle(img, (x, y), 10, (255,100,255), -1)
    plt.imshow(img)

img = annotations['RELEASE']['annolist'][imgidxs[0]]['image']['name']
points = (annotations['RELEASE']['annolist'][imgidxs[1]]['annorect']['objpos']['x'], annotations['RELEASE']['annolist'][imgidxs[1]]['annorect']['objpos']['y'])
plot_and_annotate('/home/kacper/Documents/Studia/Semester 5/Computer Vision/Human-Pose-Estimation/data/mpii_human_pose_v1/images/'+img, points)
